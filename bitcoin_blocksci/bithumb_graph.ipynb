# %%
import blocksci
import matplotlib.pyplot as plt
import matplotlib.ticker
import collections
import pandas as pd
import numpy as np
import networkx as nx
import scipy as sp
import scipy.stats
import networkx as nx

# %%
chain = blocksci.Blockchain("./bitcoin-data/")

# %%
cm_no_chain = blocksci.cluster.ClusterManager("./no_change_cluster/",chain)

# %%
address = chain.address_from_string("3C9SwDALCTLWbdsG3sCA6nqXG9oU7NT5kg")

# %%
in_tx = address.outs

# %%
for i in in_tx:
    print(i)
# Out:
# TxOut(spending_tx_index=455107734, address=ScriptHashAddress(3C9SwDALCTLWbdsG3sCA6nqXG9oU7NT5kg), value=9042788)

# %%
for i in address.outs:
    print(i)
# Out:
# TxOut(spending_tx_index=193982701, address=PubkeyHashAddress(1927LDX6isVAifgp3sXqZD6w1rnGDX96FY), value=1128581268)

# %%
address.out_txes_count()
# Out:
# 1

# %%
address.first_tx
# Out:
# Tx(len(txins)=1, len(txouts)=2, size_bytes=225, block_height=451789, tx_index=193980862)

# %%
address = chain.address_from_string("1EunngiMaLYpSQyi7ZsAPGLAZGDPw1w29j")

# %%
for i in address.outs:
    print(i)
# Out:
# TxOut(spending_tx_index=193970146, address=PubkeyHashAddress(1EsPoDfkWDTd7QXwudZFyLAaTi9meZkss2), value=8070683909)

# %%
address.txes()[0].outputs

# %%
for i in address.txes()[1].outputs:
    print(i.address.address_string)
# Out:
# 1Mpv31rLtN4R85wXqCEQRtG6yN3i7kNHU9
# 1EsPoDfkWDTd7QXwudZFyLAaTi9meZkss2

# %%
G = nx.Graph()

# %%
for i in address.txes():
    for j in i.inputs:
        in_addr = j.address.address_string
    for o in i.outputs:
        G.add_edge(in_addr,o.address.address_string)

# %%
### import networkx as nx 
#import matplotlib.pyplot as plt 
#G = nx.Graph() 
# 원하는 파라미터 이름 = 실수 (**kwds) 
#G.add_edge(1, 2, weight=5) 
#G.add_edge(2, 3, weight=3) 
#G.add_edge(3, 4, weight=2) 
#G.add_edge(2, 4, weight=1) 
#G.add_edge(1, 4, weight=0.5) # 아래는 그래프로 그리는 법 
pos=nx.spring_layout(G) 
nx.draw(G, pos=pos, with_labels=True,node_size=80,font_size=7) # edge 라벨은 weight 값을 가져온다. 
labels = nx.get_edge_attributes(G,'weight') 
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels) 
plt.figure(3,figsize=(12,12)) 
# 이 py 파일 위치하는 곳에 G.png 저장 
#plt.savefig("G.png") 
#fig=plt.figure(figsize=(5000,5000))
plt.show()

# %%
address = chain.address_from_string('1AZMTdWzP77YYAoLTmVyKpvHRzEV3Fitfz ')

# %%
for i in address.txes():
    for j in i.inputs:
        in_addr = j.address.address_string
    for o in i.outputs:
        G.add_edge(in_addr,o.address.address_string)

# %%
address = chain.address_from_string('1KQsEA5j9pqgfNUxoU8nrjqphAfdynQAJk')

# %%
for i in address.txes():
    for j in i.inputs:
        in_addr = j.address.address_string
    for o in i.outputs:
        G.add_edge(in_addr,o.address.address_string)

# %%
address = chain.address_from_string('163Qo7MfJDU5YcaDyHVuh6ewpgjxXgkoeY ')

# %%
for i in address.txes():
    for j in i.inputs:
        in_addr = j.address.address_string
    for o in i.outputs:
        G.add_edge(in_addr,o.address.address_string)

# %%
G.add_edge('3Dz5UTeczyDiL1hDb1n9wdkkMUJaNoJzw5','3C9SwDALCTLWbdsG3sCA6nqXG9oU7NT5kg')
G.add_edge('39rsJG8MBVJhVqN867YZATVXi2YRTpCC7T','3C9SwDALCTLWbdsG3sCA6nqXG9oU7NT5kg')
G.add_edge('3J7HL75yoyXRHD6grw5WA8cr52DE1nX8tB','3C9SwDALCTLWbdsG3sCA6nqXG9oU7NT5kg')
G.add_edge('3NcKV7yaKcuTyLeWMFxAFE8QsYw8pjvAG7','3C9SwDALCTLWbdsG3sCA6nqXG9oU7NT5kg')
G.add_edge('3DuRPBcUJQB1C7UuYcyFyvLujNtk8U9K7h','3C9SwDALCTLWbdsG3sCA6nqXG9oU7NT5kg')
G.add_edge('38ZSf7p11xS78Ew5thKFsC65xFuhKUpVLA','3C9SwDALCTLWbdsG3sCA6nqXG9oU7NT5kg')
G.add_edge('3CzvztXMkFEE4cjBje8BczEGBFBGV1Fyd9','3C9SwDALCTLWbdsG3sCA6nqXG9oU7NT5kg')
G.add_edge('3KydQfvQtLq5kx524HjBQ5QRwXVX4xB4Pz','3C9SwDALCTLWbdsG3sCA6nqXG9oU7NT5kg')
G.add_edge('39bUHB4b3uWBfHcjgo3PkLnj4UWxHg13b9','3C9SwDALCTLWbdsG3sCA6nqXG9oU7NT5kg')
G.add_edge('35WQ1FCEo6Tp84ZfVYWSRR6Z55iV8M3k4C','3C9SwDALCTLWbdsG3sCA6nqXG9oU7NT5kg')
G.add_edge('33VDt3rebjpYY5sxc4SgiKRcWeDZEGNp2i','3C9SwDALCTLWbdsG3sCA6nqXG9oU7NT5kg')
G.add_edge('3JubaTfzzmBNBcP2AcYZXSek4MbbARD3Na','3C9SwDALCTLWbdsG3sCA6nqXG9oU7NT5kg')

G.add_edge('3Dz5UTeczyDiL1hDb1n9wdkkMUJaNoJzw5','3NsS31JuRfoedPgNEAhDYED3w2MqkraY9P')
G.add_edge('39rsJG8MBVJhVqN867YZATVXi2YRTpCC7T','3NsS31JuRfoedPgNEAhDYED3w2MqkraY9P')
G.add_edge('3J7HL75yoyXRHD6grw5WA8cr52DE1nX8tB','3NsS31JuRfoedPgNEAhDYED3w2MqkraY9P')
G.add_edge('3NcKV7yaKcuTyLeWMFxAFE8QsYw8pjvAG7','3NsS31JuRfoedPgNEAhDYED3w2MqkraY9P')
G.add_edge('3DuRPBcUJQB1C7UuYcyFyvLujNtk8U9K7h','3NsS31JuRfoedPgNEAhDYED3w2MqkraY9P')
G.add_edge('38ZSf7p11xS78Ew5thKFsC65xFuhKUpVLA','3NsS31JuRfoedPgNEAhDYED3w2MqkraY9P')
G.add_edge('3CzvztXMkFEE4cjBje8BczEGBFBGV1Fyd9','3NsS31JuRfoedPgNEAhDYED3w2MqkraY9P')
G.add_edge('3KydQfvQtLq5kx524HjBQ5QRwXVX4xB4Pz','3NsS31JuRfoedPgNEAhDYED3w2MqkraY9P')
G.add_edge('39bUHB4b3uWBfHcjgo3PkLnj4UWxHg13b9','3NsS31JuRfoedPgNEAhDYED3w2MqkraY9P')
G.add_edge('35WQ1FCEo6Tp84ZfVYWSRR6Z55iV8M3k4C','3NsS31JuRfoedPgNEAhDYED3w2MqkraY9P')
G.add_edge('33VDt3rebjpYY5sxc4SgiKRcWeDZEGNp2i','3NsS31JuRfoedPgNEAhDYED3w2MqkraY9P')
G.add_edge('3JubaTfzzmBNBcP2AcYZXSek4MbbARD3Na','3NsS31JuRfoedPgNEAhDYED3w2MqkraY9P')

G.add_edge('3NsS31JuRfoedPgNEAhDYED3w2MqkraY9P','3DTy7LmFkrdfpGzjnTo6qazQFosucHBWwk')
G.add_edge('33mgaCYMcsGUnmJmMzRdTpS6xAY4o1SXaR','3DjbRy2Po7zHfP3xU8bR2GBG59dbyMhERc')
G.add_edge('3DTy7LmFkrdfpGzjnTo6qazQFosucHBWwk','3DjbRy2Po7zHfP3xU8bR2GBG59dbyMhERc')

# %%
pos=nx.spring_layout(G) 
nx.draw(G, pos=pos, with_labels=True,node_size=80,font_size=7) # edge 라벨은 weight 값을 가져온다. 
labels = nx.get_edge_attributes(G,'weight') 
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels) 
plt.figure(3,figsize=(12,12)) 
# 이 py 파일 위치하는 곳에 G.png 저장 
#plt.savefig("G.png") 
#fig=plt.figure(figsize=(5000,5000))
plt.show()
